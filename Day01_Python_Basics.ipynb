# %%
# ===========================
# Day 1 — Python Basics
# ===========================

# ===========================
# THEORY
# ===========================
"""theory =
Python is a high-level, easy-to-read programming language used for:
- data science
- machine learning
- automation
- web development
- scripting

Why Python?
- Simple syntax
- Huge standard library
- Massive community
- Beginner-friendly

Variables: store data in memory

Data Types:
- int: 10
- float: 10.5
- str: "Hello"
- bool: True/False
- complex: 2+3j

Type Casting: int(), float(), str()

Operators:
+  addition
-  subtraction
*  multiplication
/  division
%  remainder
** power
// floor division
"""
#print(theory)

# ===========================
# EXAMPLES
# ===========================
print("Hello Python")

a = 5
b = 6
print(a + b)

x = 10.5
print(type(x))

x_var = 10
name_var = "Tanuja"
print(x_var, name_var)

a_int = 10
b_float = 10.5
c_str = "Hello"
d_bool = True
e_complex = 2+3j
print(a_int, b_float, c_str, d_bool, e_complex)

# Type Casting
x_str = "10"
x_int = int(x_str)
y_float = float("3.14")
z_str = str(100)
print(x_int, y_float, z_str)

# Operators
add = 5 + 3
sub = 10 - 4
mul = 6 * 7
div = 15 / 3
mod = 17 % 3
power = 2 ** 3
floor = 15 // 2
print(add, sub, mul, div, mod, power, floor)

# ===========================
# PRACTICE QUESTIONS
# ===========================
a = 15
b = 25
print(a + b)

name = "Tanuja"
print("Hello", name)

x = 100
y = float(x)
print(y)

a = 2
b = 3
c = 4
print(a * b * c)

print(27 % 4)

# ===========================
# CHALLENGE QUESTIONS
# ===========================
# Swap variables
a = 5
b = 9
a, b = b, a
print(a, b)

# Even/Odd check
n = 10
print("Even" if n % 2 == 0 else "Odd")

# When user turns 100
age = 25
print(100 - age)

# Celsius to Fahrenheit
c = 37
f = (c * 9/5) + 32
print(f)

# Simple calculator with fixed values
a = 10
b = 5
op = "+"
if op == "+":
    print(a + b)
elif op == "-":
    print(a - b)
elif op == "*":
    print(a * b)
elif op == "/":
    print(a / b)
# Out:
# Hello Python
# 11
# <class 'float'>
# 10 Tanuja
# 10 10.5 Hello True (2+3j)
# 10 3.14 100
# 8 6 42 5.0 2 8 7
# 40
# Hello Tanuja
# 100.0
# 24
# 3
# 9 5
# Even
# 75
# 98.6
# 15
